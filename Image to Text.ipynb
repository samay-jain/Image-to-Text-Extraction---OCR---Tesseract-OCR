# %%
import matplotlib.pyplot as plt
import PIL
import pytesseract
import re
# %matplotlib inline

# %%
img = PIL.Image.open('img1.jpg')
plt.imshow(img)

# %%
#Convert Image to Text
pytesseract.pytesseract.tesseract_cmd = 'C:/Program Files (x86)/Tesseract-OCR/tesseract'
#pytesseract.pytesseract.tesseract_cmd = 'D:\Machine Learning Models\Image to Text extraction  - OCR\tesseract-3.02.02-win32-lib-include-dirs\tesseract-3.02.02-win32-lib-include-dirs\include\tesseract'
TESSDATA_PREFIX = 'C:/Program Files (x86)/Tesseract-OCR'

# %%
text_data = pytesseract.image_to_string(img.convert('RGB'), lang='eng')

# %%
print(text_data)
# Out:
# i//7/is’  /3‘ /'(////)/(:1' {///c/
# ///w‘(% ( //I'/// /0 /‘('(/c/
#
# This typeface is simpler and
# easier to read.

# %%
img =  PIL.Image.open('test.jpg')
plt.imshow(img)
text_data = pytesseract.image_to_string(img.convert('RGB'), lang='eng')
print(text_data)
# Out:
# Name: Sample
#
# Unique Policy Number: 12345
# Amount: 100000
#
# start Date: 1/10/2019
#
# End Date: 1/11/2019
#
# Ge0—C00rdinales: 13.89,83.49

# %%
#Extracting Specific Fields
m = re.search("Name: (\w+)", text_data)
name = m[1]
name
# Out:
# 'Sample'

# %%
img =  PIL.Image.open('test1.jpg')
plt.imshow(img)
text_data = pytesseract.image_to_string(img.convert('RGB'), lang='eng')
print(text_data)
# Out:
# %BbccDd:-:mcgHh1?
# J} Kk Ll Mm Nn O0 Ppﬂq
#
# Rr3sTt Uu Vv Ww Xx ‘J9 Zz
# @O’I23456?f89()?!:,-+Q
